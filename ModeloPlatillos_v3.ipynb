# %% [markdown]
# # Modelo final

# %%
cliente_id = 932

# %%
import pandas as pd
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import hstack

# Cargar y preparar datos
ordenes = pd.read_csv('ordenes.csv')
socios = pd.read_csv('socios_proveedores.csv')
platillos = pd.read_csv('platillos.csv')
diccionario=pd.read_csv('diccionario.csv')
def limpiar(texto):
    return re.sub(r'[^a-záéíóúñü\s]', '', str(texto).lower())

# Perfiles del cliente (por categoría)
ordenes = ordenes.merge(socios[['NumeroProveedor', 'CategoryId']], on='NumeroProveedor', how='left')
perfil_cliente = ordenes.groupby(['NumeroSocioConsumidor', 'CategoryId']).size().unstack(fill_value=0)
perfil_cliente = perfil_cliente.div(perfil_cliente.sum(axis=1), axis=0)

# Perfiles de restaurantes
platillos = platillos.dropna(subset=['Description'])
platillos['clean_desc'] = platillos['Description'].apply(limpiar)
desc_rest = platillos.groupby('NumeroProveedor')['clean_desc'].apply(' '.join).reset_index()

tfidf_vec = TfidfVectorizer(max_features=500)
rest_tfidf = tfidf_vec.fit_transform(desc_rest['clean_desc'])

cat_matrix = (
    socios[['NumeroProveedor', 'CategoryId']]
    .assign(value=1)
    .pivot_table(index='NumeroProveedor', columns='CategoryId', values='value', fill_value=0)
    .loc[desc_rest['NumeroProveedor']]
)

rest_vecs = hstack([rest_tfidf, cat_matrix.values])

#Alinear columnas cliente-restaurante 
for col in cat_matrix.columns.difference(perfil_cliente.columns):
    perfil_cliente[col] = 0
perfil_cliente = perfil_cliente[cat_matrix.columns]

# Vector del cliente (TF-IDF + perfil categoría) 
ordenes['clean_desc'] = ordenes['Description'].fillna('').apply(limpiar)
desc_cliente = ordenes.groupby('NumeroSocioConsumidor')['clean_desc'].apply(' '.join).reset_index()

# Reconstruir vectores de clientes
desc_cliente = desc_cliente[desc_cliente['NumeroSocioConsumidor'].isin(perfil_cliente.index)].reset_index(drop=True)
cli_idx_map = dict(zip(desc_cliente['NumeroSocioConsumidor'], desc_cliente.index))
tfidf_cli = tfidf_vec.transform(desc_cliente['clean_desc'])
cli_vecs = hstack([tfidf_cli, perfil_cliente.loc[desc_cliente['NumeroSocioConsumidor']].values]).tocsr()

# %%
import pandas as pd

# Cargar la tabla de órdenes
ordenes = pd.read_csv('ordenes.csv')

# Contar cuántas órdenes tiene cada cliente
top_clientes = (
    ordenes['NumeroSocioConsumidor']
        .value_counts()          # cuenta apariciones
        .reset_index()           # vuelve DataFrame
        .rename(columns={'index': 'NumeroSocioConsumidor', 
                         'NumeroSocioConsumidor': 'total_ordenes'})
)

top = (ordenes
       .groupby('NumeroSocioConsumidor')
       .size()
       .sort_values(ascending=False)
       .head(10))

top
# Out:
# NumeroSocioConsumidor
# 49       121
# 28686    107
# 932      106
# 28639     98
# 27        87
# 34132     76
# 45298     75
# 65        67
# 28097     67
# 577       67
# dtype: int64

# %%
import pandas as pd

# renombramos el diccionario una sola vez
dic = (
    diccionario.rename(columns={
        'Category Id':    'CategoryId',
        'Subcategory Id': 'SubcategoryId',
        'Categoría':      'Categoria',
        'Subcategoría':   'Subcategoria'
    })
)


def recomendar(cliente_id, n=5):
    #Checamos que exista
    if cliente_id not in cli_idx_map:
        raise ValueError("Cliente no encontrado 🤔")
    
    # Similitud coseno cliente-vs-restaurantes
    idx  = cli_idx_map[cliente_id]
    sims = cosine_similarity(cli_vecs[idx], rest_vecs).flatten()

    # DataFrame base
    resultados = desc_rest[['NumeroProveedor']].copy()
    resultados['similarity'] = sims

    # Añadimos datos del restaurante (incluye ambos IDs)
    resultados = resultados.merge(
        socios[['NumeroProveedor', 'CategoryId', 'SubcategoryId',
                'NombreRestaurante', 'latitud', 'longitud']],
        on='NumeroProveedor', how='left'
    )

    # Añadimos nombres de categoría y subcategoría 😎
    resultados = resultados.merge(
        dic[['CategoryId', 'Categoria']], on='CategoryId', how='left'
    ).merge(
        dic[['SubcategoryId', 'Subcategoria']], on='SubcategoryId', how='left'
    )

    # Orden + diversidad (top-2 por categoría)
    resultados = (resultados
                  .sort_values(by='similarity', ascending=False)
                  .groupby('CategoryId', group_keys=False)
                  .head(1))
    
    # Regresamos sólo lo que quieres mostrar
    cols = ['NombreRestaurante', 'Categoria', 'Subcategoria',
            'similarity', 'latitud', 'longitud']
    return resultados[cols].head(n)

recs = recomendar(cliente_id, 5)
recs
# Out:
#                  NombreRestaurante           Categoria  Subcategoria  \
# 276             La Casa del Panque           Cafetería    Cafeterias
# 677        Reina Comfort Food+Cafe  Desayunos y brunch        Brunch
# 988       John Ham's Fashion Drive           Americana  Hamburguesas
# 236     El Semillerito Restaurante            Italiana        Pastas
# 998  John Ham's Galerias Monterrey              Rápida  Hamburguesas
#
#      similarity    latitud    longitud
# 276    0.701069  25.670233 -100.304648
# 677    0.599111  25.654232 -100.362532
# 988    0.574318  25.651110 -100.334829
# 236    0.569837  25.672227 -100.325418
# 998    0.486343  25.680381 -100.356458

# %%
import folium
# ID del cliente y coords fijas
USER_LAT, USER_LON = 25.659990, -100.369792   # 👈 zona Tec exacta
# ----------------------------------

if recs.empty:
    print(f"No hay recs para el usuario {cliente_id}")
else:
    # Mapa centrado en la ubicación del user
    m = folium.Map(location=[USER_LAT, USER_LON], zoom_start=14)

    # Punto rojo = tú
    folium.Marker(
        [USER_LAT, USER_LON],
        tooltip="Tú estás aquí",
        icon=folium.Icon(color="red", icon="home")
    ).add_to(m)

    # Marcadores de restaurantes recomendados
    for _, r in recs.iterrows():
        popup_txt = (f"<b>{r.NombreRestaurante}</b><br>"
                     f"Similitud: {r.similarity*100:.1f}%<br>"
                     f"{r.Categoria} / {r.Subcategoria}")
        folium.Marker(
            [r.latitud, r.longitud],
            popup=popup_txt,
            tooltip=f"{r.NombreRestaurante} ({r.similarity*100:.0f}%)"
        ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab96bb530ac40b20d3e5619f8f6d2302 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab96bb530ac40b20d3e5619f8f6d2302&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab96bb530ac40b20d3e5619f8f6d2302 = L.map(
#                 &quot;map_ab96bb530ac40b20d3e5619f8f6d2302&quot;,
#                 {
#                     center: [25.65999, -100.369792],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ce8c081f83f3b9ab8661c4258c1a902 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5ce8c081f83f3b9ab8661c4258c1a902.addTo(map_ab96bb530ac40b20d3e5619f8f6d2302);
#
#
#             var marker_156a318a40004fabd609da98214548bb = L.marker(
#                 [25.65999, -100.369792],
#                 {
# }
#             ).addTo(map_ab96bb530ac40b20d3e5619f8f6d2302);
#
#
#             var icon_54640da73b0776e7ab1c4e0055dd07d2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_156a318a40004fabd609da98214548bb.bindTooltip(
#                 `&lt;div&gt;
#                      Tú estás aquí
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_156a318a40004fabd609da98214548bb.setIcon(icon_54640da73b0776e7ab1c4e0055dd07d2);
#
#
#             var marker_15d2fa82956bb60b3b63149116d88e33 = L.marker(
#                 [25.6702331, -100.3046475],
#                 {
# }
#             ).addTo(map_ab96bb530ac40b20d3e5619f8f6d2302);
#
#
#         var popup_5bcc9f917d807f4ffc2cb76d77c50c5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a40439f1f622a3a3d403116fb7f9280f = $(`&lt;div id=&quot;html_a40439f1f622a3a3d403116fb7f9280f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;La Casa del Panque&lt;/b&gt;&lt;br&gt;Similitud: 70.1%&lt;br&gt;Cafetería / Cafeterias&lt;/div&gt;`)[0];
#                 popup_5bcc9f917d807f4ffc2cb76d77c50c5a.setContent(html_a40439f1f622a3a3d403116fb7f9280f);
#
#
#
#         marker_15d2fa82956bb60b3b63149116d88e33.bindPopup(popup_5bcc9f917d807f4ffc2cb76d77c50c5a)
#         ;
#
#
#
#
#             marker_15d2fa82956bb60b3b63149116d88e33.bindTooltip(
#                 `&lt;div&gt;
#                      La Casa del Panque (70%)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_5ee83ad1a273757a4af6206dc862b473 = L.marker(
#                 [25.6542318, -100.3625318],
#                 {
# }
#             ).addTo(map_ab96bb530ac40b20d3e5619f8f6d2302);
#
#
#         var popup_4c56c9074cd65f7879a43d4c4a7dbe32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15a1450455b587adbf8ca877601d9d33 = $(`&lt;div id=&quot;html_15a1450455b587adbf8ca877601d9d33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Reina Comfort Food+Cafe&lt;/b&gt;&lt;br&gt;Similitud: 59.9%&lt;br&gt;Desayunos y brunch / Brunch&lt;/div&gt;`)[0];
#                 popup_4c56c9074cd65f7879a43d4c4a7dbe32.setContent(html_15a1450455b587adbf8ca877601d9d33);
#
#
#
#         marker_5ee83ad1a273757a4af6206dc862b473.bindPopup(popup_4c56c9074cd65f7879a43d4c4a7dbe32)
#         ;
#
#
#
#
#             marker_5ee83ad1a273757a4af6206dc862b473.bindTooltip(
#                 `&lt;div&gt;
#                      Reina Comfort Food+Cafe (60%)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_4b3c40529ec477a967062723a13427dc = L.marker(
#                 [25.6511095, -100.3348287],
#                 {
# }
#             ).addTo(map_ab96bb530ac40b20d3e5619f8f6d2302);
#
#
#         var popup_f28ab4156a5b9813ea4de052124dc293 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb7a2e835ddcafce193f0ae2aa2c4b3f = $(`&lt;div id=&quot;html_fb7a2e835ddcafce193f0ae2aa2c4b3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;John Ham&#x27;s Fashion Drive&lt;/b&gt;&lt;br&gt;Similitud: 57.4%&lt;br&gt;Americana / Hamburguesas&lt;/div&gt;`)[0];
#                 popup_f28ab4156a5b9813ea4d

# %%
import pandas as pd

#  Carga de datos
ordenes      = pd.read_csv('ordenes.csv')
socios       = pd.read_csv('socios_proveedores.csv')
diccionario  = pd.read_csv('diccionario.csv')

#  Renombra las columnas largas del diccionario solo para facilitar la vida
dic = diccionario.rename(columns={
    'Category Id':    'CategoryId',
    'Subcategory Id': 'SubcategoryId',
    'Categoría':      'Categoria',      # <-- nombre bonito
    'Subcategoría':   'Subcategoria'    # <-- nombre bonito
})

#Enriquecemos socios con los nombres de categoría y subcategoría
socios_ext = (
    socios
      .merge(dic[['CategoryId', 'Categoria']],       on='CategoryId',   how='left')
      .merge(dic[['SubcategoryId', 'Subcategoria']], on='SubcategoryId', how='left')
)

# Histórico de órdenes para tu cliente
historico = ordenes[ordenes.NumeroSocioConsumidor == cliente_id]

# Merge final para traer NombreRestaurante + Categoria + Subcategoria
hist = historico.merge(
    socios_ext[['NumeroProveedor', 'NombreRestaurante', 'Categoria', 'Subcategoria']],
    on='NumeroProveedor',
    how='left'
)

#  Selecciona las columnas que quieres ver
hist = hist[['OrderID', 'NombreRestaurante', 'Categoria', 'Subcategoria',
             'MontoTotal', 'Name']]   # ajusta 'Name' si en tu CSV tiene otro título

hist
# Out:
#      OrderID         NombreRestaurante  Categoria  Subcategoria  MontoTotal  \
# 0      48596                  Tacotote     Rápida         Tacos      744.45
# 1      48596                  Tacotote     Rápida         Tacos      744.45
# 2      48596                  Tacotote     Rápida         Tacos      744.45
# 3      48596                  Tacotote     Rápida         Tacos      744.45
# 4      48596                  Tacotote     Rápida         Tacos      744.45
# ..       ...                       ...        ...           ...         ...
# 448    52735  John Ham's Valle Oriente  Americana  Hamburguesas     2355.60
# 449    52735  John Ham's Valle Oriente  Americana  Hamburguesas     2355.60
# 450    52735  John Ham's Valle Oriente  Americana  Hamburguesas     2355.60
# 451    52735  John Ham's Valle Oriente  Americana  Hamburguesas     2355.60
# 452    52735  John Ham's Valle Oriente  Americana  Hamburguesas     2355.60
#
#                 Name
# 0      Agua de sabor
# 1      Agua de sabor
# 2      Agua de sabor
# 3      Agua de sabor
# 4      Agua de sabor
# ..               ...
# 448  Pepperoni pizza
# 449  Pepperoni pizza
# 450  Pepperoni pizza
# 451  Pepperoni pizza
# 452  Pepperoni pizza
#
# [453 rows x 6 columns]

# %%
import pandas as pd
import folium

ordenes = pd.read_csv('ordenes.csv')
visits = ordenes[ordenes.NumeroSocioConsumidor == cliente_id]
if visits.empty:
    print(f"No hay visitas para el usuario {cliente_id}")
else:
    
    lat_c = visits['latitud'].mean()
    lon_c = visits['longitud'].mean()

    #  mapa y  marcadores
    m = folium.Map(location=[lat_c, lon_c], zoom_start=14)
    for _, r in visits.iterrows():
        folium.Marker([r.latitud, r.longitud], popup=r.Name).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18f7ea1eb04281fe4a5187a607684423 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18f7ea1eb04281fe4a5187a607684423&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18f7ea1eb04281fe4a5187a607684423 = L.map(
#                 &quot;map_18f7ea1eb04281fe4a5187a607684423&quot;,
#                 {
#                     center: [25.67238059056604, -100.34553594433963],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56289d055b74a02b1b794a42809e7614 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_56289d055b74a02b1b794a42809e7614.addTo(map_18f7ea1eb04281fe4a5187a607684423);
#
#
#             var marker_cd62d5e9e64333ae0113bff4e5a58345 = L.marker(
#                 [25.6722871, -100.3675237],
#                 {
# }
#             ).addTo(map_18f7ea1eb04281fe4a5187a607684423);
#
#
#         var popup_061b2086ecb6dc10a9da775cc931e7be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f2e6b64f5b17eb795d829017974ec81 = $(`&lt;div id=&quot;html_7f2e6b64f5b17eb795d829017974ec81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Agua de sabor&lt;/div&gt;`)[0];
#                 popup_061b2086ecb6dc10a9da775cc931e7be.setContent(html_7f2e6b64f5b17eb795d829017974ec81);
#
#
#
#         marker_cd62d5e9e64333ae0113bff4e5a58345.bindPopup(popup_061b2086ecb6dc10a9da775cc931e7be)
#         ;
#
#
#
#
#             var marker_e90581e395d6bff4e9e705ff3b477901 = L.marker(
#                 [25.6722871, -100.3675237],
#                 {
# }
#             ).addTo(map_18f7ea1eb04281fe4a5187a607684423);
#
#
#         var popup_4ac461edcf904cc7d878125660d35f98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8899a11c3160a7dcd9019d48f6e1fd36 = $(`&lt;div id=&quot;html_8899a11c3160a7dcd9019d48f6e1fd36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arroz&lt;/div&gt;`)[0];
#                 popup_4ac461edcf904cc7d878125660d35f98.setContent(html_8899a11c3160a7dcd9019d48f6e1fd36);
#
#
#
#         marker_e90581e395d6bff4e9e705ff3b477901.bindPopup(popup_4ac461edcf904cc7d878125660d35f98)
#         ;
#
#
#
#
#             var marker_ff91ed92fe5b289c5dc0d002fa024a8c = L.marker(
#                 [25.6722871, -100.3675237],
#                 {
# }
#             ).addTo(map_18f7ea1eb04281fe4a5187a607684423);
#
#
#         var popup_1fabf1fded7a0d099f8852ebf9ec1f75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d0842bc1397442b0326990b5a905112 = $(`&lt;div id=&quot;html_6d0842bc1397442b0326990b5a905112&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Parrillada de Arrachera&lt;/div&gt;`)[0];
#                 popup_1fabf1fded7a0d099f8852ebf9ec1f75.setContent(html_6d0842bc1397442b0326990b5a905112);
#
#
#
#         marker_ff91ed92fe5b289c5dc0d002fa024a8c.bindPopup(popup_1fabf1fded7a0d099f8852ebf9ec1f75)
#         ;
#
#
#
#
#             var marker_79935b0386e0db40610d10ca656adf75 = L.marker(
#                 [25.6722871, -100.3675237],
#                 {
# }
#             ).addTo(map_18f7ea1eb04281fe4a5187a607684423);
#
#
#         var popup_899c48019c974afce31f0cd3c05a36b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1c9ed8c8d95da9a2320f739d74583c3 = $(`&lt;div id=&quot;html_a1c9ed8c8d95da9a2320f739d74583c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Refresco de lata&lt;/div&gt;`)[0];
#                 popup_899c48019c974afce31f0cd3c05a36b4.setContent(html_a1c9ed8c8d95da9a2320f739d74583c3);
#
#
#
#         marker_79935b0386e0db40610d10ca656adf75.bindPopup(popup_899c48019c974afce31f0cd3c05a36b4)
#         ;
#
#
#
#
#             var marker_710aaa12a978847b2c67e74d3b28a895 = L.marker(
#                 [25.6722871, -100.3675237],
#                 {
# }
#             ).addTo(map_18f7ea1eb04281fe4a5187a607684423);
#
#
#         var popup_e778db4e395775a4c1e179564b52461d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_436a5598a862ce6c93e109115f493ab0 = $(`&lt;div id=&quot;html_436a5598a862ce6c93e109115f493ab0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Refresco de refil&lt;/div&gt;`)[0];
#                 popup_e778db4e395775a4c1e179564b52461d.setContent(html_436a5598a862ce6c93e109115f4

# %%
import random
import pandas as pd
from math import radians, sin, cos, sqrt, atan2

# Definir el área metropolitana de Monterrey (aprox. bounding box)
LAT_MIN, LAT_MAX = 25.6134, 25.8260
LON_MIN, LON_MAX = -100.4518, -100.2137

def asignar_ubicacion_random():
    """Devuelve una tupla (lat, lon) random dentro de Monterrey."""
    lat = random.uniform(LAT_MIN, LAT_MAX)
    lon = random.uniform(LON_MIN, LON_MAX)
    return lat, lon

# %%
def haversine(lat1, lon1, lat2, lon2):
    """Calcula la distancia en km entre dos puntos lat/lon."""
    R = 6371  # radio tierra en km
    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)
    a = sin(dlat/2)**2 + cos(radians(lat1)) * cos(radians(lat2)) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    return R * c

# %%
user_lat, user_lon=25.659990, -100.369792
print(f"Ubicación user asignada: {user_lat:.5f}, {user_lon:.5f}")
# Out:
# Ubicación user asignada: 25.65999, -100.36979

# %%
# Calculamos la distancia de cada restaurante al user
recs['distance_km'] = recs.apply(
    lambda row: haversine(user_lat, user_lon, row['latitud'], row['longitud']),
    axis=1
)

# %%
# Ordenamos primero por similarity (antes rec_score) y luego por distancia
recs_ordenadas = recs.sort_values(
    by=['distance_km','similarity'],
    ascending=[True, True]
)
top5 = (
    recs_ordenadas
        .drop_duplicates(subset='NombreRestaurante')  # o 'NombreRestaurante'
        .head(5)
)

print("Top 10 recomendaciones cercanas y afines:")
top5
# Out:
# Top 10 recomendaciones cercanas y afines:
#                  NombreRestaurante           Categoria  Subcategoria  \
# 677        Reina Comfort Food+Cafe  Desayunos y brunch        Brunch
# 998  John Ham's Galerias Monterrey              Rápida  Hamburguesas
# 988       John Ham's Fashion Drive           Americana  Hamburguesas
# 236     El Semillerito Restaurante            Italiana        Pastas
# 276             La Casa del Panque           Cafetería    Cafeterias
#
#      similarity    latitud    longitud  distance_km
# 677    0.599111  25.654232 -100.362532     0.969282
# 998    0.486343  25.680381 -100.356458     2.631885
# 988    0.574318  25.651110 -100.334829     3.640926
# 236    0.569837  25.672227 -100.325418     4.650786
# 276    0.701069  25.670233 -100.304648     6.627679

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import folium

# Crear GeoDataFrame de recomendaciones ---
geometry = [Point(xy) for xy in zip(top5['longitud'], top5['latitud'])]
gdf_recs = gpd.GeoDataFrame(top5, geometry=geometry, crs="EPSG:4326")

#  GeoDataFrame de la ubicación del usuario ---
user_geom = Point(user_lon, user_lat)
gdf_user = gpd.GeoDataFrame(
    pd.DataFrame({'Nombre': ['Usuario']}),
    geometry=[user_geom],
    crs="EPSG:4326"
)

# Iniciar el mapa folium centrado en el usuario 
m = folium.Map(location=[user_lat, user_lon], zoom_start=13)

#  Añadir marcadores de restaurantes 
for _, row in gdf_recs.iterrows():
    folium.Marker(
        location=[row.geometry.y, row.geometry.x],
        popup=row['NombreRestaurante'],
        icon=folium.Icon(color='blue', icon='cutlery', prefix='fa')
    ).add_to(m)

#  Añadir marcador de usuario
folium.Marker(
    location=[user_lat, user_lon],
    popup='Usuario',
    icon=folium.Icon(color='red', icon='star')
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9e3af36a092ce292a423554579ccf4a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9e3af36a092ce292a423554579ccf4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9e3af36a092ce292a423554579ccf4a = L.map(
#                 &quot;map_f9e3af36a092ce292a423554579ccf4a&quot;,
#                 {
#                     center: [25.65999, -100.369792],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4f1b2530d551929d7104fe32aadfe57 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f4f1b2530d551929d7104fe32aadfe57.addTo(map_f9e3af36a092ce292a423554579ccf4a);
#
#
#             var marker_95313865db1565be264c82c06898fc74 = L.marker(
#                 [25.6542318, -100.3625318],
#                 {
# }
#             ).addTo(map_f9e3af36a092ce292a423554579ccf4a);
#
#
#             var icon_4fd500073faab888957fca51c5431c43 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cutlery&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9ccf7b1920cbc54f8bba05c0d12424c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_084e43a47020ab42c25d7caccef84071 = $(`&lt;div id=&quot;html_084e43a47020ab42c25d7caccef84071&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Reina Comfort Food+Cafe&lt;/div&gt;`)[0];
#                 popup_9ccf7b1920cbc54f8bba05c0d12424c3.setContent(html_084e43a47020ab42c25d7caccef84071);
#
#
#
#         marker_95313865db1565be264c82c06898fc74.bindPopup(popup_9ccf7b1920cbc54f8bba05c0d12424c3)
#         ;
#
#
#
#
#                 marker_95313865db1565be264c82c06898fc74.setIcon(icon_4fd500073faab888957fca51c5431c43);
#
#
#             var marker_71fecdefa21fef8129ec8af3cebac5ac = L.marker(
#                 [25.680381, -100.3564579],
#                 {
# }
#             ).addTo(map_f9e3af36a092ce292a423554579ccf4a);
#
#
#             var icon_fb828ef5ef081c150ea4e452b2663b83 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cutlery&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d31c833719bdf820ed1b938a5b05338e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb12360bce98bc8476979041bf9881e6 = $(`&lt;div id=&quot;html_fb12360bce98bc8476979041bf9881e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;John Ham&#x27;s Galerias Monterrey&lt;/div&gt;`)[0];
#                 popup_d31c833719bdf820ed1b938a5b05338e.setContent(html_fb12360bce98bc8476979041bf9881e6);
#
#
#
#         marker_71fecdefa21fef8129ec8af3cebac5ac.bindPopup(popup_d31c833719bdf820ed1b938a5b05338e)
#         ;
#
#
#
#
#                 marker_71fecdefa21fef8129ec8af3cebac5ac.setIcon(icon_fb828ef5ef081c150ea4e452b2663b83);
#
#
#             var marker_c989d59d623a2ce1765053a8edb8e718 = L.marker(
#                 [25.6511095, -100.3348287],
#                 {
# }
#             ).addTo(map_f9e3af36a092ce292a423554579ccf4a);
#
#
#             var icon_8dcfead99acfae055c0388fe54aaedbc = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cutlery&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4be67e78deb3cc69d2c4695658401e17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_682bc261627304f841f5cb22e8c7f1c5 = $(`&lt;div id=&quot;html_682bc261627304f841f5cb22e8c7f1c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;John Ham&#x27;s Fashion Drive&lt;/div&gt;`)[0];
#                 popup_4be67e78deb3cc69d2c4695658401e17.setContent(html_682bc261627304f841f5cb22e8c7f1c5);
#
#
#
#         marker_c989d59d623a2ce1765053a8edb8e718.bindPopup(popup_4be67e78deb3cc69d2c4695658401e17)
#         ;
#
#
#
#
#                 marker_c989d59d623a2ce1765053a8edb8e718.setIcon(icon_8dcfead99acfae055c0388fe54aaedbc);
